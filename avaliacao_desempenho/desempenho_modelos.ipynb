# %% [markdown]
# # Desempenho de Modelos Ollama
#
# Neste notebook será avaliado alguns modelos disponíveis no Ollama, com objetivo de definir qual utilizar para um projeto de um agente de IA.
#
# A princípio os modelos avaliados serão:
#
# - llama3.2:3b
# - phi4-mini:3.8b
# - phi3:3.8b
#
# Para isso, serão avaliados resposta, geração de tokens por segundo, consumo de memória RAM.
#
# As prompts serão os mesmo, algumas ideais:
#
# - Por que o céu é azul?
# - Se eu tenho 3 maçãs e você me tira 2, com quantas maçãs você fica?
# - Um fazendeiro precisa atravessar um rio com um lobo, uma cabra e um repolho. Ele tem um barco que só pode carregar ele mesmo e mais um item. Se o lobo ficar sozinho com a cabra, ele a come. Se a cabra ficar sozinha com o repolho, ela o come. Como o fazendeiro pode atravessar todos com segurança?

# %%
# Importando bibliotecas

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
